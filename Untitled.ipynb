# %%
import dicom
import inspect
import pylab
import numpy

# %%
images = [dicom.read_file('data/001/3/1.3.12.2.1107.5.1.4.51914.300000061218061226187000007' + str(i + 101)[1:] + '.dcm') for i in range(16)]
masks = [dicom.read_file('data/001/ROI_MASK/roimask_00' + str(i + 101)[1:] + '.dcm') for i in range(16)]

pairs = list(zip(images, masks))
for pair in pairs:
    pylab.imshow(pair[0].pixel_array, cmap=pylab.cm.bone)
    pylab.show()
    print(pair[0]['0020','0013'], '\n', pair[0]['0020','1041'])
# Out:
# (0020, 0013) Instance Number                     IS: '1'
#  (0020, 1041) Slice Location                      DS: '-1888.5'
# (0020, 0013) Instance Number                     IS: '2'
#  (0020, 1041) Slice Location                      DS: '-1868.5'
# (0020, 0013) Instance Number                     IS: '3'
#  (0020, 1041) Slice Location                      DS: '-1848.5'
# (0020, 0013) Instance Number                     IS: '4'
#  (0020, 1041) Slice Location                      DS: '-1828.5'
# (0020, 0013) Instance Number                     IS: '5'
#  (0020, 1041) Slice Location                      DS: '-1808.5'
# (0020, 0013) Instance Number                     IS: '6'
#  (0020, 1041) Slice Location                      DS: '-1788.5'
# (0020, 0013) Instance Number                     IS: '7'
#  (0020, 1041) Slice Location                      DS: '-1768.5'
# (0020, 0013) Instance Number                     IS: '8'
#  (0020, 1041) Slice Location                      DS: '-1748.5'
# ...

# %%
bin(111)
# Out:
# '0b1101111'

# %%
de = images[0][(0x20,0x13)]

# %%
dv = de.value

# %%
import os

# %%
    pylab.imshow(numpy.multiply(numpy.multiply(img > 500, img ), img < 1300), cmap=pylab.cm.gray)
    pylab.show()

# %%
nd = numpy.array([[1,2,3],[5,6,7]])
nd.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-544c3274c8ae> in <module>()
# ----> 1 nd = numpy.array([[1,2,3],[5,6,7]])
#       2 nd.size
#
# NameError: name 'numpy' is not defined

# %%
pair
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-29eff9c741d4> in <module>()
# ----> 1 pair
#
# NameError: name 'pair' is not defined

# %%
pairs[0]
# Out:
# ((0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.51914.30000006121806122618700000701
# (0008, 0020) Study Date                          DA: '20061218'
# (0008, 0021) Series Date                         DA: '20061218'
# (0008, 0022) Acquisition Date                    DA: '20061218'
# (0008, 0023) Content Date                        DA: '20061218'
# (0008, 0030) Study Time                          TM: '081600.0'
# (0008, 0031) Series Time                         TM: '082330.812000'
# (0008, 0032) Acquisition Time                    TM: '082311.303189'
# (0008, 0033) Content Time                        TM: '082300.0'
# (0008, 0050) Accession Number                    SH: 'ANONYMOUS'
# (0008, 0060) Modality                            CS: 'CT'
# ...
