# %%
import numpy as np
from glob import glob

# %%
for file in glob('data/*'):
    print(file)
    f = np.load(file).all()
    f['roi'] = f['tag'][:,:,:,1]
    f.pop('tag')
    np.save('slim'+file, f)
# Out:
# data/malign320.npy
# data/malign298.npy
# data/benign083.npy
# data/benign044.npy
# data/malign158.npy
# data/malign006.npy
# data/malign122.npy
# data/malign249.npy
# data/malign185.npy
# data/malign213.npy
# data/malign008.npy
# data/malign012.npy
# data/malign077.npy
# data/malign241.npy
# data/malign178.npy
# data/malign318.npy
# data/malign146.npy
# data/benign032.npy
# data/malign030.npy
# data/benign092.npy
# data/malign159.npy
# data/malign265.npy
# data/malign190.npy
# data/benign068.npy
# data/malign037.npy
# data/benign037.npy
# data/malign194.npy
# data/malign142.npy
# data/malign173.npy
# data/malign059.npy
# data/malign109.npy
# data/benign085.npy
# data/malign211.npy
# data/malign312.npy
# data/malign321.npy
# data/benign084.npy
# data/benign014.npy
# data/malign258.npy
# data/malign154.npy
# data/malign346.npy
# data/benign013.npy
# data/benign090.npy
# data/malign338.npy
# data/malign324.npy
# data/malign103.npy
# data/malign327.npy
# data/malign347.npy
# ...
