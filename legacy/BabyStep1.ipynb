# %%
import dicom
import inspect
import pylab
import numpy as np
from glob import glob
import os
import matplotlib
import matplotlib.pyplot as plt
import re
from keras.utils.np_utils import to_categorical

# %%
X = np.load('babyX1.npy')
y = np.load('babyY1.npy')
print(X.shape, y.shape)
# Out:
# (1336, 80, 80) (1336,)

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *

# %%
shuffle = np.random.permutation(np.arange(1336))
X = X[shuffle] ** 0.5
X = (X - np.max(X) / 2) / np.max(X)
X = X.reshape(1336, 80, 80, 1)
y = to_categorical(y[shuffle])

# %%
model = Sequential()
model.add(Convolution2D(32, 3, 3, input_shape=(80, 80, 1)))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
# Note: Keras does automatic shape inference.
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(2))
model.add(Activation('softmax'))

sgd = SGD(lr=0.3, decay=1e-4, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['precision', 'recall'])

# %%
def sym_generator(x, y, batch_num, sym = False):
    b = [i for i, c in enumerate(y) if c[0] == 1]
    m = [i for i, c in enumerate(y) if c[1] == 1]
    while True:
        a = np.random.randint(batch_num) if sym == False else batch_num // 2
        batch_index = np.hstack((np.random.permutation(b)[:a],np.random.permutation(m)[:batch_num - a]))
        yield (x[batch_index], y[batch_index])
        
model.fit_generator(
    sym_generator(X[:1000].reshape(1000,80,80,1), y[:1000], 64), 
    samples_per_epoch=1024, 
    nb_epoch=40,
    validation_data = sym_generator(X[1000:].reshape(336, 80, 80, 1), y[1000:], 128, True),
    nb_val_samples = 128
)
# Out:
# Epoch 1/40
# 1024/1024 [==============================] - 12s - loss: 1.0081 - precision: 0.4717 - recall: 0.4717 - val_loss: 0.6908 - val_precision: 0.5246 - val_recall: 0.5246
# Epoch 2/40
# 1024/1024 [==============================] - 12s - loss: 0.6971 - precision: 0.5801 - recall: 0.5801 - val_loss: 0.7012 - val_precision: 0.4754 - val_recall: 0.4754
# Epoch 3/40
# 1024/1024 [==============================] - 12s - loss: 0.7089 - precision: 0.5439 - recall: 0.5439 - val_loss: 0.6469 - val_precision: 0.6639 - val_recall: 0.6639
# Epoch 4/40
# 1024/1024 [==============================] - 12s - loss: 0.6531 - precision: 0.6738 - recall: 0.6738 - val_loss: 0.5891 - val_precision: 0.7172 - val_recall: 0.7172
# Epoch 5/40
# 1024/1024 [==============================] - 12s - loss: 0.5930 - precision: 0.7031 - recall: 0.7031 - val_loss: 0.6029 - val_precision: 0.6926 - val_recall: 0.6926
# Epoch 6/40
# 1024/1024 [==============================] - 12s - loss: 0.6292 - precision: 0.6768 - recall: 0.6768 - val_loss: 0.5440 - val_precision: 0.7705 - val_recall: 0.7705
# Epoch 7/40
# 1024/1024 [==============================] - 12s - loss: 0.6937 - precision: 0.7568 - recall: 0.7568 - val_loss: 0.8240 - val_precision: 0.5656 - val_recall: 0.5656
# Epoch 8/40
# 1024/1024 [==============================] - 12s - loss: 0.5905 - precision: 0.7188 - recall: 0.7188 - val_loss: 0.4994 - val_precision: 0.7828 - val_recall: 0.7828
# Epoch 9/40
# 1024/1024 [==============================] - 12s - loss: 0.5021 - precision: 0.7637 - recall: 0.7637 - val_loss: 0.4704 - val_precision: 0.7951 - val_recall: 0.7951
# Epoch 27/40
# 1024/1024 [==============================] - 12s - loss: 0.0181 - precision: 0.9961 - recall: 0.9961 - val_loss: 0.9927 - val_precision: 0.8730 - val_recall: 0.8730
# Epoch 28/40
# 1024/1024 [==============================] - 12s - loss: 0.0141 - precision: 0.9951 - recall: 0.9951 - val_loss: 1.1523 - val_precision: 0.8361 - val_recall: 0.8361
# Epoch 29/40
# 1024/1024 [==============================] - 12s - loss: 0.0139 - precision: 0.9961 - recall: 0.9961 - val_loss: 1.1141 - val_precision: 0.8525 - val_recall: 0.8525
# Epoch 30/40
# 1024/1024 [==============================] - 12s - loss: 0.0501 - precision: 0.9824 - recall: 0.9824 - val_loss: 1.0400 - val_precision: 0.8689 - val_recall: 0.8689
# Epoch 31/40
# 1024/1024 [==============================] - 12s - loss: 0.0182 - precision: 0.9941 - recall: 0.9941 - val_loss: 1.2692 - val_precision: 0.8402 - val_recall: 0.8402
# Epoch 32/40
# 1024/1024 [==============================] - 12s - loss: 0.0110 - precision: 0.9951 - recall: 0.9951 - val_loss: 1.4045 - val_precision: 0.8074 - val_recall: 0.8074
# Epoch 33/40
# 1024/1024 [==============================] - 12s - loss: 0.0146 - precision: 0.9941 - recall: 0.9941 - val_loss: 1.3827 - val_precision: 0.8443 - val_recall: 0.8443
# Epoch 34/40
# 1024/1024 [==============================] - 12s - loss: 0.0505 - precision: 0.9902 - recall: 0.9902 - val_loss: 1.0844 - val_precision: 0.8443 - val_recall: 0.8443
# Epoch 35/40
# 1024/1024 [==============================] - 12s - loss: 0.0051 - precision: 0.9990 - recall: 0.9990 - val_loss: 1.2635 - val_precision: 0.8689 - val_recall: 0.8689
# Epoch 36/40
# 1024/1024 [==============================] - 12s - loss: 0.0062 - precision: 0.9980 - recall: 0.9980 - val_loss: 1.2445 - val_precision: 0.8361 - val_recall: 0.8361
# Epoch 37/40
# 1024/1024 [==============================] - 12s - loss: 0.0090 - precision: 0.9971 - recall: 0.9971 - val_loss: 1.3770 - val_precision: 0.8525 - val_recall: 0.8525
# Epoch 38/40
# 1024/1024 [==============================] - 12s - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4889 - val_precision: 0.8525 - val_recall: 0.8525
# Epoch 39/40
# 1024/1024 [==============================] - 12s - loss: 0.0010 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.4813 - val_precision: 0.8648 - val_recall: 0.8648
# Epoch 40/40
# 1024/1024 [==============================] - 12s - loss: 0.0757 - precision: 0.9834 - recall: 0.9834 - val_loss: 1.2856 - val_precision: 0.8648 - val_recall: 0.8648

# %%
w1 = layer1.get_weights()[0]

# %%
plt.rcParams['figure.figsize'] = (15.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'bone'

# %%
for i in range(4):
    for j in range(8):
        k = w1[:,:,:,i * 8 + j]
        plt.subplot(4, 8, i*8 + j + 1)
        plt.imshow(k.reshape((3,3)), plt.cm.bone, extent=[j * 10, j* 10 + 3, j * 10, j * 10 + 3])
        plt.axis('off')
        
plt.show()

# %%
intermediate_layer_model = Model(input=model.input,
                                 output=layer1.output)
intermediate_output = intermediate_layer_model.predict(X.reshape(1336, 80, 80, 1))

# %%
orig = X[0]
activations = intermediate_output[0]
print(orig.shape, activations.shape)
# Out:
# (80, 80, 1) (78, 78, 32)

# %%
plt.imshow(orig.reshape(80,80), plt.cm.bone)
plt.show()
print (y[0])
# Out:
# [ 0.  1.]

# %%
for i in range(4):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(4, 8, i*8 + j + 1)
        plt.imshow(k.reshape((78,78)), plt.cm.bone, extent=[j * 10, j* 10 + 3, j * 10, j * 10 + 3])
        plt.axis('off')
        
plt.show()

# %%
from keras import backend as K

# with a Sequential model
get1 = K.function([model.layers[0].input],
                                  [model.layers[1].output])
intermediate_image = get1([X])

activations = intermediate_image[0][0]

for i in range(4):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(4, 8, i*8 + j + 1)
        plt.imshow(k.reshape((78,78)), plt.cm.bone, extent=[j * 10, j* 10 + 3, j * 10, j * 10 + 3])
        plt.axis('off')
        
plt.show()

# %%
from keras import backend as K

# with a Sequential model
get1 = K.function([model.layers[0].input],
                                  [model.layers[3].output])
intermediate_image = get1([X])

activations = intermediate_image[0][0]

for i in range(4):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(4, 8, i*8 + j + 1)
        plt.imshow(k.reshape((76,76)), plt.cm.bone, extent=[j * 10, j* 10 + 3, j * 10, j * 10 + 3])
        plt.axis('off')
        
plt.show()

# %%
from keras import backend as K

# with a Sequential model
get1 = K.function([model.layers[0].input],
                                  [model.layers[4].output])
intermediate_image = get1([X])

activations = intermediate_image[0][0]

for i in range(4):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(4, 8, i*8 + j + 1)
        plt.imshow(k.reshape((38,38)), plt.cm.bone, extent=[j * 10, j* 10 + 3, j * 10, j * 10 + 3])
        plt.axis('off')
        
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'bone'

# with a Sequential model
get1 = K.function([model.layers[0].input, K.learning_phase()],
                                  [model.layers[7].output])
intermediate_image = get1([X[:1], 0])

activations = intermediate_image[0][0]

for i in range(8):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(8, 8, i*8 + j + 1)
        plt.imshow(k.reshape((36,36)), plt.cm.bone)
        plt.axis('off')
        
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'bone'

i = 23

# with a Sequential model
get1 = K.function([model.layers[0].input, K.learning_phase()],
                                  [model.layers[9].output])
intermediate_image = get1([X[i: i+1], 0])

activations = intermediate_image[0][0]

plt.subplot(5,4,1)
plt.imshow(X[i: i+1].reshape(80,80), plt.cm.bone)

print(y[i:i+1])

for i in range(8):
    for j in range(8):
        k = activations[:,:,i * 8 + j]
        plt.subplot(10, 8, 16 + i*8 + j + 1)
        plt.imshow(k.reshape((34,34)), plt.cm.bone)
        plt.axis('off')
        
plt.show()
# Out:
# [[ 0.  1.]]

# %%
def evaluate(model):
    e1 = model.evaluate(X[:1000], y[:1000])
    print ('loss: %f\t prec: %f\trecall: %f' % tuple(e1))
    e2 = model.evaluate(X[1000:], y[1000:])
    print ('validation loss: %f\t prec: %f\trecall: %f' % tuple(e2))

# %%
evaluate(model)
# Out:
# 1000/1000 [==============================] - 3s
# loss: 0.000282	 prec: 1.000000	recall: 1.000000
# 336/336 [==============================] - 1s
# validation loss: 0.689428	 prec: 0.904762	recall: 0.904762

# %%
gen = sym_generator(X[1000:].reshape(336, 80, 80, 1), y[1000:], 128, True)

# %%
xx, yy = next(gen)
model.evaluate(xx, yy)
# Out:
# 124/124 [==============================] - 0s
# [1.2777748780865823, 0.83870968126481582, 0.83870968126481582]

# %%
model.predict_classes(np.array([xx[0]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e828c2f116b> in <module>()
# ----> 1 model.predict_classes(np.array([xx[0]]))
#
# NameError: name 'model' is not defined

# %%
len(Out[280])
# Out:
# 1

# %% [markdown]
# ## Internal Accuracy

# %%
def hot_range_2D(dicom_image: dicom.dataset.FileDataset):
    pixels = dicom_image.pixel_array
    xaxis = np.sum(pixels, axis = 0)
    yaxis = np.sum(pixels, axis = 1)
    xHot = [i for i, v in enumerate(xaxis) if v > 0]
    yHot = [i for i, v in enumerate(yaxis) if v > 0]
    if len(xHot) != 0 and len(yHot) != 0:
        return ((xHot[0], xHot[-1]), (yHot[0], yHot[-1]))

def crop8080(range_2d):
    ((xl, xr), (yu, yd)) = range_2d
    xm = (xl + xr) // 2
    ym = (yu + yd) // 2
    return ((xm - 40, xm + 40), (ym - 40, ym + 40))

isMask = lambda fname : re.search('roimask_\d{4}.dcm', fname) != None

baseDir = 'project1/CCM_Data'

# %%
def preprocess(X):
    num = X.shape[0]
    X = X ** 0.5
    X = (X - np.max(X) / 2) / np.max(X)
    X = X.reshape(num, 80, 80, 1)
    return X

# %%
benigns = np.load('benign_cropped.npy')

stats = []
for b in benigns:
    res = model.predict_classes(preprocess(np.array(list(map(lambda slice: slice['roi'], b)))))
    stats.append(res)
    
sss = [s.sum() / len(s) for s in stats]

plt.plot(sss, 'rx')
plt.show()
# Out:
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 5/5 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 13/13 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 20/20 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s

# %%
benigns = np.load('malig_cropped.npy')

stats = []
for b in benigns:
    res = model.predict_classes(preprocess(np.array(list(map(lambda slice: slice['roi'], b)))))
    stats.append(res)
    
sss = [s.sum() / len(s) for s in stats]

plt.plot(sss, 'rx')
plt.show()
# Out:
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 6/6 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 5/5 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 7/7 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 6/6 [==============================] - 0s
# 6/6 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 6/6 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 6/6 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 6/6 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 6/6 [==============================] - 0s
# 2/2 [==============================] - 0s
# 9/9 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 6/6 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 6/6 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 6/6 [==============================] - 0s
# 5/5 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 8/8 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 5/5 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 7/7 [==============================] - 0s
# 10/10 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 6/6 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 7/7 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 6/6 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 6/6 [==============================] - 0s
# 5/5 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 6/6 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 5/5 [==============================] - 0s
# 10/10 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 7/7 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 6/6 [==============================] - 0s
# 2/2 [==============================] - 0s
# 5/5 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 5/5 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 2/2 [==============================] - 0s
# 1/1 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s
# 3/3 [==============================] - 0s
# 1/1 [==============================] - 0s
# 6/6 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 2/2 [==============================] - 0s
# 2/2 [==============================] - 0s
# 4/4 [==============================] - 0s
# 4/4 [==============================] - 0s
# 2/2 [==============================] - 0s
# 3/3 [==============================] - 0s
# 3/3 [==============================] - 0s
# 4/4 [==============================] - 0s

# %%
model.evaluate(X, y)
# Out:
#  - ETA: 0s
# [0.18638839238997887, 0.97529940084069078, 0.97529940084069078]

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=90,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    vertical_flip=True)

gen = datagen.flow(X, y, batch_size=256)

# %%
xx, yy = next(gen)
model.evaluate(xx, yy)
# Out:
# 56/56 [==============================] - 0s
# [1.7073227678026472, 0.8214285799435207, 0.8214285799435207]

# %%
model.save('model-babystep1-default.h5')
